# %%
import pandas as pd
import numpy as np

# %%
ep = pd.read_csv("master_data_ready.csv")

# %%
ep.shape
# Out:
# (200000, 15)

# %%
ep.dtypes
# Out:
# job_id          object
# vertical        object
# company         object
# post_date       object
# fill_date       object
# time_to_fill    object
# salary           int64
# location        object
# city            object
# state           object
# zip             object
# county          object
# region_state    object
# latitude        object
# longitude       object
# dtype: object

# %%
len(ep.dtypes)
# Out:
# 15

# %%
ep.columns
# Out:
# Index(['job_id', 'vertical', 'company', 'post_date', 'fill_date',
#        'time_to_fill', 'salary', 'location', 'city', 'state', 'zip', 'county',
#        'region_state', 'latitude', 'longitude'],
#       dtype='object')

# %%
ep.head()
# Out:
#                              job_id                vertical    company  \
# 0  20198581751789701529910950958638  Information Technology        NaN
# 1   8895868916034283132954081837418  Information Technology  Medtronic
# 2   1519847330480116680516242585467  Information Technology        NaN
# 3  92511853348028679647877877985294  Information Technology        NaN
# 4    490138684948094100363899533762  Information Technology   Mindteck
#
#     post_date   fill_date time_to_fill  salary                    location  \
# 0  2017-07-02          \N           \N   56563                         NaN
# 1  2018-04-20          \N           \N   98222              Northridge, CA
# 2  2017-08-01          \N           \N   63761                         NaN
# 3  2016-08-27  2016-08-30            3   54231                         NaN
# 4  2018-02-20  2018-02-20            0   84921  Research Triangle Park, NC
#
#                      city state    zip       county  \
# ...

# %%
ep = ep.rename(columns={"job_id":"id", "region_state":"region", "post_date":"postDate", "fill_date":"fillDate", "time_to_fill":"timeToFill", "latitude":"lat","longitude":"long"})

# %%
ep.dtypes
# Out:
# id            object
# vertical      object
# company       object
# postDate      object
# fillDate      object
# timeToFill    object
# salary         int64
# location      object
# city          object
# state         object
# zip           object
# county        object
# region        object
# lat           object
# long          object
# dtype: object

# %%
list(ep)
# Out:
# ['id',
#  'vertical',
#  'company',
#  'postDate',
#  'fillDate',
#  'timeToFill',
#  'salary',
#  'location',
#  'city',
#  'state',
#  'zip',
#  'county',
#  'region',
#  'lat',
#  'long']

# %%
ep[list(ep)[1]].value_counts()
# Out:
# Information Technology    200000
# Name: vertical, dtype: int64

# %%
# PROBLEM 2

# %%
ep = ep.replace(r'\\N', np.nan, regex=True)

# %%
ep.head()
# Out:
#                                  Id                Vertical    Company  \
# 0  20198581751789701529910950958638  Information Technology        NaN
# 1   8895868916034283132954081837418  Information Technology  Medtronic
# 2   1519847330480116680516242585467  Information Technology        NaN
# 3  92511853348028679647877877985294  Information Technology        NaN
# 4    490138684948094100363899533762  Information Technology   Mindteck
#
#      Postdate    Filldate Timetofill  Salary                    Location  \
# 0  2017-07-02         NaN        NaN   56563                         NaN
# 1  2018-04-20         NaN        NaN   98222              Northridge, CA
# 2  2017-08-01         NaN        NaN   63761                         NaN
# 3  2016-08-27  2016-08-30          3   54231                         NaN
# 4  2018-02-20  2018-02-20          0   84921  Research Triangle Park, NC
#
#                      City State    Zip       County  \
# ...

# %%
[x.capitalize() for x in ep]
# Out:
# ['Id',
#  'Vertical',
#  'Company',
#  'Postdate',
#  'Filldate',
#  'Timetofill',
#  'Salary',
#  'Location',
#  'City',
#  'State',
#  'Zip',
#  'County',
#  'Region',
#  'Lat',
#  'Long']

# %%
ep.columns = [x.capitalize() for x in ep]
ep.dtypes
# Out:
# Id            object
# Vertical      object
# Company       object
# Postdate      object
# Filldate      object
# Timetofill    object
# Salary         int64
# Location      object
# City          object
# State         object
# Zip           object
# County        object
# Region        object
# Lat           object
# Long          object
# dtype: object

# %%
ep
# Out:
#                                       Id                Vertical  \
# 0       20198581751789701529910950958638  Information Technology
# 1        8895868916034283132954081837418  Information Technology
# 2        1519847330480116680516242585467  Information Technology
# 3       92511853348028679647877877985294  Information Technology
# 4         490138684948094100363899533762  Information Technology
# 5       74657902746882254946742123272434  Information Technology
# 6       67959912699822604603156520211049  Information Technology
# 7       62960553541696238196645947323426  Information Technology
# 8       90717759116185198593932094841046  Information Technology
# 9       16387272974132263790431897281915  Information Technology
# 10      72696625716373834009704285573063  Information Technology
# 11       7574193811517788303631671726249  Information Technology
# 12       9522301324327623359690770686252  Information Technology
# ...

# %%
#pd.to_numeric(ep, errors='coerce')

# %%
#ep['Timetofill'] = pd.to_numeric(ep['Timetofill'], errors='coerce')

# %%
ep.apply(pd.to_numeric, errors='ignore').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
# Id            200000 non-null object
# Vertical      200000 non-null object
# Company       89592 non-null object
# Postdate      200000 non-null object
# Filldate      48882 non-null object
# Timetofill    48882 non-null float64
# Salary        200000 non-null int64
# Location      89270 non-null object
# City          87327 non-null object
# State         89177 non-null object
# Zip           85068 non-null float64
# County        85390 non-null object
# Region        84408 non-null object
# Lat           86405 non-null float64
# Long          86405 non-null float64
# dtypes: float64(4), int64(1), object(10)
# memory usage: 22.9+ MB

# %%
ep.columns
# Out:
# Index(['Id', 'Vertical', 'Company', 'Postdate', 'Filldate', 'Timetofill',
#        'Salary', 'Location', 'City', 'State', 'Zip', 'County', 'Region', 'Lat',
#        'Long'],
#       dtype='object')

# %%
master_clean = ep.drop(['Lat', 'Long'], axis = 1)

# %%
master_clean.head()
# Out:
#                                  Id                Vertical    Company  \
# 0  20198581751789701529910950958638  Information Technology        NaN
# 1   8895868916034283132954081837418  Information Technology  Medtronic
# 2   1519847330480116680516242585467  Information Technology        NaN
# 3  92511853348028679647877877985294  Information Technology        NaN
# 4    490138684948094100363899533762  Information Technology   Mindteck
#
#      Postdate    Filldate Timetofill  Salary                    Location  \
# 0  2017-07-02         NaN        NaN   56563                         NaN
# 1  2018-04-20         NaN        NaN   98222              Northridge, CA
# 2  2017-08-01         NaN        NaN   63761                         NaN
# 3  2016-08-27  2016-08-30          3   54231                         NaN
# 4  2018-02-20  2018-02-20          0   84921  Research Triangle Park, NC
#
#                      City State    Zip       County  \
# ...

# %%
master_clean.dtypes
# Out:
# Id            object
# Vertical      object
# Company       object
# Postdate      object
# Filldate      object
# Timetofill    object
# Salary         int64
# Location      object
# City          object
# State         object
# Zip           object
# County        object
# Region        object
# dtype: object

# %%
master_clean[master_clean['State'] == 'NY']
# Out:
#                                       Id                Vertical  \
# 43      49166544275228979011485468005581  Information Technology
# 47      37537451312284214352975523963512  Information Technology
# 56      32216824414038021036854127631301  Information Technology
# 42        406721259826597271166136103276  Information Technology
# 53       7955450235772249401977199367187  Information Technology
# 61      45230337933216733091735774621770  Information Technology
# 70      32300234787209199670389747356731  Information Technology
# 79        681377002829632837068544453736  Information Technology
# 91       2294022611392523687558580960170  Information Technology
# ...

# %%
master_clean.median()['Timetofill']
# Out:
# 12.0

# %%
master_clean.head()
# Out:
#                                  Id                Vertical    Company  \
# 0  20198581751789701529910950958638  Information Technology        NaN
# 1   8895868916034283132954081837418  Information Technology  Medtronic
# 2   1519847330480116680516242585467  Information Technology        NaN
# 3  92511853348028679647877877985294  Information Technology        NaN
# 4    490138684948094100363899533762  Information Technology   Mindteck
#
#      Postdate    Filldate Timetofill  Salary                    Location  \
# 0  2017-07-02         NaN        NaN   56563                         NaN
# 1  2018-04-20         NaN        NaN   98222              Northridge, CA
# 2  2017-08-01         NaN        NaN   63761                         NaN
# 3  2016-08-27  2016-08-30          3   54231                         NaN
# 4  2018-02-20  2018-02-20          0   84921  Research Triangle Park, NC
#
#                      City State    Zip       County  \
# ...

# %%
master_clean['Timetofill'] = master_clean['Timetofill'].fillna(value = 12.0)
master_clean
# Out:
#                                       Id                Vertical  \
# 0       20198581751789701529910950958638  Information Technology
# 1        8895868916034283132954081837418  Information Technology
# 2        1519847330480116680516242585467  Information Technology
# 3       92511853348028679647877877985294  Information Technology
# 4         490138684948094100363899533762  Information Technology
# 5       74657902746882254946742123272434  Information Technology
# 6       67959912699822604603156520211049  Information Technology
# 7       62960553541696238196645947323426  Information Technology
# 8       90717759116185198593932094841046  Information Technology
# 9       16387272974132263790431897281915  Information Technology
# 10      72696625716373834009704285573063  Information Technology
# 11       7574193811517788303631671726249  Information Technology
# 12       9522301324327623359690770686252  Information Technology
# ...

# %%
master_clean[master_clean['State'] == 'NJ'][['Company', 'Postdate', 'Salary']].dropna()
# Out:
#                                                  Company    Postdate  Salary
# 248                                           Siemens AG  2018-03-21  117154
# 347                                        Stefanini Inc  2017-01-25  104023
# 425              On The Border Mexican Grill and Cantina  2017-08-02   17115
# 474                                                Ricoh  2018-03-15   39479
# 545                                           BNY Mellon  2016-10-28  104219
# 634                                       NFI Industries  2018-04-14   81348
# 724                                    Quest Diagnostics  2017-08-29   36549
# 833                                    Bed Bath & Beyond  2018-01-18  123018
# 916                                       APN Consulting  2018-07-17  109966
# 965                      Stewart's All American | Walker  2017-08-18   35169
# 974                           Partner's Consulting, Inc.  2017-01-19   86999
# ...

# %%
master_clean[master_clean['State'] == 'NY']
# Out:
#                                       Id                Vertical  \
# 43      49166544275228979011485468005581  Information Technology
# 47      37537451312284214352975523963512  Information Technology
# 56      32216824414038021036854127631301  Information Technology
# 71       4667196791289643164323208292672  Information Technology
# 122     17686258734635581425901950904423  Information Technology
# 201       894124309792585221392368131845  Information Technology
# 284     68180000463505362721268597011820  Information Technology
# 308     50469534955455002631890344958016  Information Technology
# 315     26626974554550569739436120606642  Information Technology
# 324     75506920553773445036596485697789  Information Technology
# 350     86033830263392417359471988955876  Information Technology
# 363       467895701373045028283543226368  Information Technology
# 394     63999053417238671662217757939290  Information Technology
# ...
